# %%
print("Hello world")
# Out:
# Hello world

# %%
nome = "Rayane"
print(nome)
# Out:
# Rayane

# %%
# analise de dados
import pandas as pd 

dados = {"Nome": ["Ana","Victhor","Rayane"],"Idade": [18,17,18]}
df = pd.DataFrame(dados)
df
# Out:
#       Nome  Idade
# 0      Ana     18
# 1  Victhor     17
# 2   Rayane     18

# %%
#Célula 8 - Visualização
import pandas as pd
import matplotlib.pyplot as plt

plt.plot (
    df["Nome"],
    df["Idade"])

plt.title("Idade dos Participantes")
plt.xlable("Nome")
plt.ylable("Idade")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 10
#       6     df["Nome"],
#       7     df["Idade"])
#       8
#       9 plt.title("Idade dos Participantes")
# ---> 10 plt.xlable("Nome")
#      11 plt.ylable("Idade")
#      12
#      13 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'
